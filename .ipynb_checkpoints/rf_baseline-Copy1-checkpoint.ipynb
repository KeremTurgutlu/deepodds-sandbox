# %%
import pandas as pd
import sqlite3
import numpy as np
import pickle
from sklearn.ensemble import RandomForestClassifier
from pandas.api.types import is_string_dtype, is_numeric_dtype
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import label_binarize
from sklearn.metrics import log_loss
from sklearn.calibration import CalibratedClassifierCV
import shap
import rfpimp
from joblib import Parallel, delayed
from sklearn.model_selection import ParameterGrid

# %%
import matplotlib.pyplot as plt

# %%
pd.options.display.max_columns = 1000
pd.options.display.max_rows = 1000

# %%
path = '/Users/princegrover/Documents/msan/app_dev/git/data/'

# %%
data_final = pd.read_pickle(path + 'data_final_form')

# %%
conn = sqlite3.connect(path + 'database.sqlite')

# %%
team_data = pd.read_sql("SELECT * FROM Team;", conn)

# %%
team_data[:2]
# Out:
#    id  team_api_id  team_fifa_api_id team_long_name team_short_name
# 0   1         9987             673.0       KRC Genk             GEN
# 1   2         9993             675.0   Beerschot AC             BAC

# %%
team_data.drop(labels=['team_short_name','id', 'team_fifa_api_id'], axis=1,inplace=True)

# %%
team_data[:2]
# Out:
#    team_api_id team_long_name
# 0         9987       KRC Genk
# 1         9993   Beerschot AC

# %%
#code for formation creation
# data_final.head()

# data_final.isnull().sum()

# data_final.columns[:100]

# x = np.array(data_final.loc[100, ['away_player_X2',
#        'away_player_X3', 'away_player_X4', 'away_player_X5', 'away_player_X6',
#        'away_player_X7', 'away_player_X8', 'away_player_X9', 'away_player_X10',
#        'away_player_X11']])

# y = np.array(data_final.loc[100, ['away_player_Y2',
#        'away_player_Y3', 'away_player_Y4', 'away_player_Y5', 'away_player_Y6',
#        'away_player_Y7', 'away_player_Y8', 'away_player_Y9', 'away_player_Y10',
#        'away_player_Y11']])

# plt.scatter(x,y)


# for i in range(1,12): 
#     data_final.apply(lambda x: (x[f'home_player_X{i}',f'home_player_Y{i}']))

# l = []

# for i in range(1,12):
#     x = f'away_player_X{i}'
#     y = f'away_player_Y{i}'
#     l.extend(list(zip(data_final[x],data_final[y])))

# pos2idx = {j:i for i,j in enumerate(set(l))}

# len(pos2idx)

# pos2idx

# data_final.apply(lambda x: (x.loc[:,'home_player_X1'],x.loc[:,'home_player_Y1']),axis=0)

# pd.Series(list(zip(data_final.home_player_X1,data_final.home_player_Y1))).map(pos2idx)

# for i in range(1,12):
#     data_final[f'home_player_{i}_pos'] = pd.Series(list(zip(data_final[f'home_player_X{i}'],data_final[f'home_player_Y{i}']))).map(pos2idx)

# for i in range(1,12):
#     data_final[f'away_player_{i}_pos'] = pd.Series(list(zip(data_final[f'away_player_X{i}'],data_final[f'away_player_Y{i}']))).map(pos2idx)

# data_final.head()

# data_final.columns[-22:]

# data_final.shape

# list(np.sort(data_final.loc[:,['home_player_1_pos', 'home_player_2_pos', 'home_player_3_pos',
#        'home_player_4_pos', 'home_player_5_pos', 'home_player_6_pos',
#        'home_player_7_pos', 'home_player_8_pos', 'home_player_9_pos',
#        'home_player_10_pos', 'home_player_11_pos']].values,axis=1))

# df = pd.DataFrame(np.sort(data_final.loc[:,['home_player_1_pos', 'home_player_2_pos', 'home_player_3_pos',
#        'home_player_4_pos', 'home_player_5_pos', 'home_player_6_pos',
#        'home_player_7_pos', 'home_player_8_pos', 'home_player_9_pos',
#        'home_player_10_pos', 'home_player_11_pos']].values,axis=1),columns = ['home_player_1_pos', 'home_player_2_pos', 'home_player_3_pos',
#        'home_player_4_pos', 'home_player_5_pos', 'home_player_6_pos',
#        'home_player_7_pos', 'home_player_8_pos', 'home_player_9_pos',
#        'home_player_10_pos', 'home_player_11_pos'])

# df1 = pd.DataFrame(np.sort(data_final.loc[:,['away_player_1_pos', 'away_player_2_pos', 'away_player_3_pos',
#        'away_player_4_pos', 'away_player_5_pos', 'away_player_6_pos',
#        'away_player_7_pos', 'away_player_8_pos', 'away_player_9_pos',
#        'away_player_10_pos', 'away_player_11_pos']].values,axis=1),columns = ['away_player_1_pos', 'away_player_2_pos', 'away_player_3_pos',
#        'away_player_4_pos', 'away_player_5_pos', 'away_player_6_pos',
#        'away_player_7_pos', 'away_player_8_pos', 'away_player_9_pos',
#        'away_player_10_pos', 'away_player_11_pos'])

# df1

# df['home_formation'] = df.apply(
#     lambda x: '%s_%s_%s_%s_%s_%s_%s_%s_%s_%s_%s' % (x['home_player_1_pos'], x['home_player_2_pos'], 
#                                                     x['home_player_3_pos'], x['home_player_4_pos'], 
#                                                     x['home_player_5_pos'], x['home_player_6_pos'],
#                                                    x['home_player_7_pos'], x['home_player_8_pos'],
#                                                    x['home_player_9_pos'], x['home_player_10_pos'],
#                                                    x['home_player_11_pos']),
#     axis=1)

# df

# df1['home_formation'] = df1.apply(
#     lambda x: '%s_%s_%s_%s_%s_%s_%s_%s_%s_%s_%s' % (x['away_player_1_pos'], x['away_player_2_pos'], 
#                                                     x['away_player_3_pos'], x['away_player_4_pos'], 
#                                                     x['away_player_5_pos'], x['away_player_6_pos'],
#                                                    x['away_player_7_pos'], x['away_player_8_pos'],
#                                                    x['away_player_9_pos'], x['away_player_10_pos'],
#                                                    x['away_player_11_pos']),
#     axis=1)

# df.home_formation

# set(pd.concat((df.home_formation,df1.home_formation),axis=0))

# df['away_formation'] = df1.apply(
#     lambda x: '%s_%s_%s_%s_%s_%s_%s_%s_%s_%s_%s' % (x['away_player_1_pos'], x['away_player_2_pos'], 
#                                                     x['away_player_3_pos'], x['away_player_4_pos'], 
#                                                     x['away_player_5_pos'], x['away_player_6_pos'],
#                                                    x['away_player_7_pos'], x['away_player_8_pos'],
#                                                    x['away_player_9_pos'], x['away_player_10_pos'],
#                                                    x['away_player_11_pos']),
#     axis=1)

# set(df.away_formation).difference(set(df.home_formation))

# df1['home_formation'].map(form2idx)

# form2idx = {j:f'formation_{i}' for i,j in enumerate(set(pd.concat((df.home_formation,df1.home_formation),axis=0)))}

# form_df = pd.DataFrame()
# form_df['home_form'] =df['home_formation'].map(form2idx)
# form_df['away_form'] = df1['home_formation'].map(form2idx)

# form_df.shape

# data_final = pd.concat((data_final,form_df),axis=1)

# data_final.drop(['home_player_X1', 'home_player_X2',
#        'home_player_X3', 'home_player_X4', 'home_player_X5', 'home_player_X6',
#        'home_player_X7', 'home_player_X8', 'home_player_X9', 'home_player_X10',
#        'home_player_X11', 'away_player_X1', 'away_player_X2', 'away_player_X3',
#        'away_player_X4', 'away_player_X5', 'away_player_X6', 'away_player_X7',
#        'away_player_X8', 'away_player_X9', 'away_player_X10',
#        'away_player_X11', 'home_player_Y1', 'home_player_Y2', 'home_player_Y3',
#        'home_player_Y4', 'home_player_Y5', 'home_player_Y6', 'home_player_Y7',
#        'home_player_Y8', 'home_player_Y9', 'home_player_Y10',
#        'home_player_Y11', 'away_player_Y1', 'away_player_Y2', 'away_player_Y3',
#        'away_player_Y4', 'away_player_Y5', 'away_player_Y6', 'away_player_Y7',
#        'away_player_Y8', 'away_player_Y9', 'away_player_Y10',
#        'away_player_Y11'],axis = 1,inplace = True)

# data_final.to_pickle('data/deep_odds/data_final_form')

# data_final.shape

# np.unique(np.sort(np.array([[1,2,3],[4,50,6],[4,50,6]]),axis=1),axis=0)

# {j:i for i,j in enumerate(list(np.unique(np.sort(data_final.loc[:,['home_player_1_pos', 'home_player_2_pos', 'home_player_3_pos',
#        'home_player_4_pos', 'home_player_5_pos', 'home_player_6_pos',
#        'home_player_7_pos', 'home_player_8_pos', 'home_player_9_pos',
#        'home_player_10_pos', 'home_player_11_pos']].values,axis=1),axis=0)))}

# for e in zip(data_final.loc[:,'home_player_X1'],data_final.loc[:,'home_player_Y1']): print(e)



# data_final.apply(lambda x: (x.loc[:,'home_player_X1'],x.loc[:,'home_player_Y1']))

# data_final.groupby(['away_player_X1','away_player_X2',
#        'away_player_X3', 'away_player_X4', 'away_player_X5', 'away_player_X6',
#        'away_player_X7', 'away_player_X8', 'away_player_X9', 'away_player_X10',
#        'away_player_X11']).count().reset_index()

# %%
# repetetive column
data_final.drop('league_id_y', axis=1, inplace=True)

# %%
data_final.drop(['id','country_id','home_player_1', 'home_player_2',
       'home_player_3', 'home_player_4', 'home_player_5', 'home_player_6',
       'home_player_7', 'home_player_8', 'home_player_9', 'home_player_10',
       'home_player_11', 'away_player_1', 'away_player_2', 'away_player_3',
       'away_player_4', 'away_player_5', 'away_player_6', 'away_player_7',
       'away_player_8', 'away_player_9', 'away_player_10', 'away_player_11'],axis = 1, inplace = True)

# %%
data_final.drop(['home_player_1_pos', 'home_player_2_pos', 'home_player_3_pos',
       'home_player_4_pos', 'home_player_5_pos', 'home_player_6_pos',
       'home_player_7_pos', 'home_player_8_pos', 'home_player_9_pos',
       'home_player_10_pos', 'home_player_11_pos', 'away_player_1_pos',
       'away_player_2_pos', 'away_player_3_pos', 'away_player_4_pos',
       'away_player_5_pos', 'away_player_6_pos', 'away_player_7_pos',
       'away_player_8_pos', 'away_player_9_pos', 'away_player_10_pos',
       'away_player_11_pos'],axis=1,inplace = True)

# %%
data_final.drop(['goal', 'shoton', 'shotoff', 'foulcommit', 'card',
       'cross', 'corner', 'possession'],axis=1, inplace = True)

# %%
data_final.dropna(how='any',inplace=True)

# %%
bookkeeper_data = pd.read_feather(path + 'bookkeeper-data')

# %%
bookkeeper_data[:2]
# Out:
#    B365H  B365D  B365A   BWH   BWD    BWA  IWH  IWD   IWA   LBH  LBD   LBA  \
# 0   1.29    5.5   11.0  1.30  4.75   8.25  1.3  4.4   8.5  1.25  4.5  10.0
# 1   1.20    6.5   15.0  1.22  5.50  10.00  1.2  5.2  11.0  1.20  5.0  11.0
#
#    PSH  PSD  PSA   WHH  WHD   WHA   SJH  SJD   SJA   VCH  VCD   VCA   GBH  \
# 0  NaN  NaN  NaN  1.25  4.5  10.0  1.25  5.0  10.0  1.28  5.5  12.0  1.30
# 1  NaN  NaN  NaN  1.17  5.5  12.0  1.20  5.5  12.0  1.25  6.0  13.0  1.22
#
#     GBD   GBA   BSH  BSD   BSA  match_api_id
# 0  4.75  10.0  1.29  4.5  11.0        489042
# 1  5.50  13.0  1.22  5.0  13.0        489043

# %%
bookkeeper_data.shape
# Out:
# (8045, 31)

# %% [markdown]
# * Training : upto last-2 seasons of each league
# * Validation : 2nd last season
# * Test: last season

# %%
# data is only for 3 leagues
data_final.league_id_x.unique()
# Out:
# array([ 1729,  7809, 21518], dtype=uint64)

# %%
# adding year column
data_final['year'] = data_final.date.dt.year

# %%
league_years = data_final[['league_id_x','year']].drop_duplicates().reset_index(drop=True)

# %%
league_years
# Out:
#     league_id_x  year
# 0          1729  2010
# 1          1729  2011
# 2          1729  2012
# 3          1729  2013
# 4          1729  2014
# 5          1729  2015
# 6          1729  2016
# 7          7809  2010
# 8          7809  2011
# 9          7809  2012
# 10         7809  2013
# 11         7809  2014
# 12         7809  2015
# 13         7809  2016
# 14        21518  2010
# 15        21518  2011
# 16        21518  2012
# 17        21518  2013
# 18        21518  2014
# 19        21518  2015
# 20        21518  2016

# %%
# validation set
val_yr_lg = league_years.groupby('league_id_x').tail(2).groupby(
    'league_id_x').head(1)
val_yr_lg
# Out:
#     league_id_x  year
# 5          1729  2015
# 12         7809  2015
# 19        21518  2015

# %%
# test set
test_yr_lg = league_years.groupby('league_id_x').tail(1)
test_yr_lg
# Out:
#     league_id_x  year
# 6          1729  2016
# 13         7809  2016
# 20        21518  2016

# %% [markdown]
# ### More features and null treatment

# %%
data_final['month'] = data_final.date.dt.month
data_final['dow'] = data_final.date.dt.dayofweek
data_final['hour '] = data_final.date.dt.hour

# %%
def convert_cats(train, col_not_convert=[], test=None):
    """
    Convert columns in a training and test dataframe
    into category codes 
    
    train: Training dataframe
    col_not_convert: list of columns which are string type and which you don't want to convert
    test: Test/ Validation set (Mapping from category codes from training)
    """

    for n, c in train.items():
        if is_string_dtype(c) and n not in col_not_convert:
            train[n] = c.astype('category').cat.as_ordered()

    if test is not None:
        for n, c in test.items():
            if (n in train.columns) and (train[n].dtype.name == 'category'):
                test[n] = pd.Categorical(
                    c, categories=train[n].cat.categories, ordered=True)

    cols = list(train.columns[train.dtypes == 'category'])
    for c in cols:
        train[c] = train[c].astype('category').cat.codes
        if test is not None: test[c] = test[c].astype('category').cat.codes

# %%
# convert string to cats

convert_cats(data_final)

# %%
# removing nulls from int/float based columns, replace with -1 as this is what we did for string type also

data_final.fillna(-1, inplace=True)

# %%
data_final[:2]
# Out:
#      league_id_x  season  stage       date  match_api_id  home_team_api_id  \
# 463         1729       1      2 2010-03-24        658592              8456
# 474         1729       1     21 2010-03-16        658936              8528
#
#      away_team_api_id  home_team_goal  away_team_goal  \
# 463              8668               0               2
# 474             10252               1               2
#
#      home_player_1_overall_rating  home_player_1_potential  \
# 463                            84                       85
# 474                            77                       83
#
#      home_player_1_preferred_foot  home_player_1_attacking_work_rate  \
# 463                             1                                  2
# 474                             1                                  2
#
#      home_player_1_defensive_work_rate  home_player_1_crossing  \
# 463                                  4                      21
# 474                                  4                      23
#
#      home_player_1_finishing  home_player_1_heading_accuracy  \
# 463                       21                              21
# 474                       23                              23
#
#      home_player_1_short_passing  home_player_1_volleys  \
# 463                           38                     19
# 474                           26                     12
#
#      home_player_1_dribbling  home_player_1_curve  \
# 463                       21                   19
# 474                       23                   12
#
#      home_player_1_free_kick_accuracy  home_player_1_long_passing  \
# 463                                 9                          77
# 474                                10                          80
#
#      home_player_1_ball_control  home_player_1_acceleration  \
# 463                          21                          54
# 474                          22                          50
#
#      home_player_1_sprint_speed  home_player_1_agility  \
# 463                          52                     45
# 474                          51                     54
#
#      home_player_1_reactions  home_player_1_balance  home_player_1_shot_power  \
# 463                       67                     67                        47
# 474                       67                     49                        22
#
#      home_player_1_jumping  home_player_1_stamina  home_player_1_strength  \
# 463                     79                     68                      78
# 474                     78                     67                      70
#
#      home_player_1_long_shots  home_player_1_aggression  \
# 463                        21                        75
# 474                        23                        59
#
#      home_player_1_interceptions  home_player_1_positioning  \
# 463                           74                         51
# 474                           77                         49
#
#      home_player_1_vision  home_player_1_penalties  home_player_1_marking  \
# 463                    62                       83                     29
# 474                    69                       67                     23
#
#      home_player_1_standing_tackle  home_player_1_sliding_tackle  \
# 463                             21                             8
# 474                             27                            23
#
#      home_player_1_gk_diving  home_player_1_gk_handling  \
# 463                       89                         80
# 474                       80                         78
#
#      home_player_1_gk_kicking  home_player_1_gk_positioning  \
# 463                        77                            82
# 474                        80                            73
#
#      home_player_1_gk_reflexes  home_player_2_overall_rating  \
# 463                         90                            78
# 474                         78                            73
#
#      home_player_2_potential  home_player_2_preferred_foot  \
# 463                       87                             1
# 474                       75                             1
#
#      home_player_2_attacking_work_rate  home_player_2_defensive_work_rate  \
# 463                                  4                                 10
# 474                                  3                                 10
#
#      home_player_2_crossing  home_player_2_finishing  \
# 463                      60                       35
# 474                      63                       22
#
#      home_player_2_heading_accuracy  home_player_2_short_passing  \
# 463                              86                           66
# 474                              66                           56
#
#      home_player_2_volleys  home_player_2_dribbling  home_player_2_curve  \
# 463                     44                       57                   45
# 474                     20                       57                   22
#
#      home_player_2_free_kick_accuracy  home_player_2_long_passing  \
# 463                                31                          63
# 474                                37                          45
#
#      home_player_2_ball_control  home_player_2_acceleration  \
# 463                          62                          86
# 474                          65                          68
#
#      home_player_2_sprint_speed  home_player_2_agility  \
# 463                          87                     62
# 474                          73                     46
#
#      home_player_2_reactions  home_player_2_balance  home_player_2_shot_power  \
# 463                       76                     85                        62
# 474                       66                     62                        59
#
#      home_player_2_jumping  home_player_2_stamina  home_player_2_strength  \
# 463                     91                     85                      90
# 474                     75                     78                      77
#
#      home_player_2_long_shots  home_player_2_aggression  \
# 463                        29                        86
# 474                        40                        65
#
#      home_player_2_interceptions  home_player_2_positioning  \
# 463                           64                         71
# 474                           76                         77
#
#      home_player_2_vision  home_player_2_penalties  home_player_2_marking  \
# 463                    57                       69                     76
# 474                    61                       64                     78
#
#      home_player_2_standing_tackle  home_player_2_sliding_tackle  \
# 463                             84                            83
# 474                             77                            75
#
#      home_player_2_gk_diving  home_player_2_gk_handling  \
# 463                       13                         22
# 474                       12                         23
#
#      home_player_2_gk_kicking  home_player_2_gk_positioning  \
# 463                        63                            22
# 474                        45                            23
#
#      home_player_2_gk_reflexes  home_player_3_overall_rating  \
# 463                         22                            84
# 474                         23                            77
#
#      home_player_3_potential  home_player_3_preferred_foot  \
# 463                       87                             1
# 474                       79                             1
#
#      home_player_3_attacking_work_rate  home_player_3_defensive_work_rate  \
# 463                                  5                                 12
# 474                                  5                                 12
#
#      home_player_3_crossing  home_player_3_finishing  \
# 463                      40                       39
# 474                      47                       25
#
#      home_player_3_heading_accuracy  home_player_3_short_passing  \
# 463                              84                           70
# 474                              82                           72
#
#      home_player_3_volleys  home_player_3_dribbling  home_player_3_curve  \
# 463                     35                       64                   59
# 474                     11                       63                   47
#
#      home_player_3_free_kick_accuracy  home_player_3_long_passing  \
# 463                                72                          68
# 474                                12                          81
#
#      home_player_3_ball_control  home_player_3_acceleration  \
# 463                          65                          78
# 474                          72                          66
#
#      home_player_3_sprint_speed  home_player_3_agility  \
# 463                          79                     60
# 474                          67                     59
#
#      home_player_3_reactions  home_player_3_balance  home_player_3_shot_power  \
# 463                       76                     82                        87
# 474                       74                     69                        46
#
#      home_player_3_jumping  home_player_3_stamina  home_player_3_strength  \
# 463                     87                     88                      90
# 474                     80                     76                      81
#
#      home_player_3_long_shots  home_player_3_aggression  \
# 463                        82                        88
# 474                        25                        75
#
#      home_player_3_interceptions  home_player_3_positioning  \
# 463                           84                         85
# 474                           76                         77
#
#      home_player_3_vision  home_player_3_penalties  home_player_3_marking  \
# 463                    62                       78                     85
# 474                    63                       66                     78
#
#      home_player_3_standing_tackle  home_player_3_sliding_tackle  \
# 463                             88                            89
# 474                             77                            71
#
#      home_player_3_gk_diving  home_player_3_gk_handling  \
# 463                        7                         23
# 474                        7                         25
#
#      home_player_3_gk_kicking  home_player_3_gk_positioning  \
# 463                        68                            23
# 474                        81                            25
#
#      home_player_3_gk_reflexes  home_player_4_overall_rating  \
# 463                         23                            79
# 474                         25                            76
#
#      home_player_4_potential  home_player_4_preferred_foot  \
# 463                       85                             1
# 474                       77                             1
#
#      home_player_4_attacking_work_rate  home_player_4_defensive_work_rate  \
# 463                                  5                                 12
# 474                                  5                                 14
#
#      home_player_4_crossing  home_player_4_finishing  \
# 463                      62                       60
# 474                      31                       41
#
#      home_player_4_heading_accuracy  home_player_4_short_passing  \
# 463                              72                           76
# 474                              78                           64
#
#      home_player_4_volleys  home_player_4_dribbling  home_player_4_curve  \
# 463                     66                       67                   61
# 474                     51                       34                   22
#
#      home_player_4_free_kick_accuracy  home_player_4_long_passing  \
# 463                                52                          73
# 474                                30                          64
#
#      home_player_4_ball_control  home_player_4_acceleration  \
# 463                          83                          81
# 474                          55                          73
#
#      home_player_4_sprint_speed  home_player_4_agility  \
# 463                          83                     58
# 474                          78                     49
#
#      home_player_4_reactions  home_player_4_balance  home_player_4_shot_power  \
# 463                       80                     83                        76
# 474                       56                     77                        61
#
#      home_player_4_jumping  home_player_4_stamina  home_player_4_strength  \
# 463                     78                     81                      87
# 474                     84                     75                      89
#
#      home_player_4_long_shots  home_player_4_aggression  \
# 463                        65                        71
# 474                        32                        81
#
#      home_player_4_interceptions  home_player_4_positioning  \
# 463                           79                         82
# 474                           62                         61
#
#      home_player_4_vision  home_player_4_penalties  home_player_4_marking  \
# 463                    85                       86                     79
# 474                    47                       70                     70
#
#      home_player_4_standing_tackle  home_player_4_sliding_tackle  \
# 463                             80                            82
# 474                             81                            74
#
#      home_player_4_gk_diving  home_player_4_gk_handling  \
# 463                        6                         23
# 474                       13                         23
#
#      home_player_4_gk_kicking  home_player_4_gk_positioning  \
# 463                        73                            23
# 474                        64                            23
#
#      home_player_4_gk_reflexes  home_player_5_overall_rating  \
# 463                         23                            78
# 474                         23                            73
#
#      home_player_5_potential  home_player_5_preferred_foot  \
# 463                       84                             1
# 474                       78                             0
#
#      home_player_5_attacking_work_rate  home_player_5_defensive_work_rate  \
# 463                                  4                                  9
# 474                                  4                                  9
#
#      home_player_5_crossing  home_player_5_finishing  \
# 463                      74                       41
# 474                      77                       57
#
#      home_player_5_heading_accuracy  home_player_5_short_passing  \
# 463                              71                           80
# 474                              50                           67
#
#      home_player_5_volleys  home_player_5_dribbling  home_player_5_curve  \
# 463                     67                       80                   68
# 474                     66                       68                   47
#
#      home_player_5_free_kick_accuracy  home_player_5_long_passing  \
# 463                                77                          79
# 474                                79                          62
#
#      home_player_5_ball_control  home_player_5_acceleration  \
# 463                          82                          77
# 474                          69                          83
#
#      home_player_5_sprint_speed  home_player_5_agility  \
# 463                          73                     75
# 474                          82                     63
#
#      home_player_5_reactions  home_player_5_balance  home_player_5_shot_power  \
# 463                       80                     73                        66
# 474                       70                     60                        78
#
#      home_player_5_jumping  home_player_5_stamina  home_player_5_strength  \
# 463                     78                     81                      79
# 474                     69                     82                      78
#
#      home_player_5_long_shots  home_player_5_aggression  \
# 463                        57                        83
# 474                        76                        72
#
#      home_player_5_interceptions  home_player_5_positioning  \
# 463                           77                         80
# 474                           64                         71
#
#      home_player_5_vision  home_player_5_penalties  home_player_5_marking  \
# 463                    69                       70                     80
# 474                    62                       64                     80
#
#      home_player_5_standing_tackle  home_player_5_sliding_tackle  \
# 463                             78                            77
# 474                             77                            76
#
#      home_player_5_gk_diving  home_player_5_gk_handling  \
# 463                        7                         23
# 474                       12                         23
#
#      home_player_5_gk_kicking  home_player_5_gk_positioning  \
# 463                        79                            23
# 474                        62                            23
#
#      home_player_5_gk_reflexes  home_player_6_overall_rating  \
# 463                         23                            79
# 474                         23                            77
#
#      home_player_6_potential  home_player_6_preferred_foot  \
# 463                       82                             0
# 474                       83                             0
#
#      home_player_6_attacking_work_rate  home_player_6_defensive_work_rate  \
# 463                                  2                                 11
# 474                                  4                                 10
#
#      home_player_6_crossing  home_player_6_finishing  \
# 463                      84                       75
# 474                      78                       68
#
#      home_player_6_heading_accuracy  home_player_6_short_passing  \
# 463                              43                           78
# 474                              60                           76
#
#      home_player_6_volleys  home_player_6_dribbling  home_player_6_curve  \
# 463                     67                       82                   70
# 474                     77                       84                   62
#
#      home_player_6_free_kick_accuracy  home_player_6_long_passing  \
# 463                                75                          74
# 474                                43                          74
#
#      home_player_6_ball_control  home_player_6_acceleration  \
# 463                          82                          79
# 474                          78                          84
#
#      home_player_6_sprint_speed  home_player_6_agility  \
# 463                          82                     78
# 474                          83                     80
#
#      home_player_6_reactions  home_player_6_balance  home_player_6_shot_power  \
# 463                       74                     66                        77
# 474                       67                     78                        84
#
#      home_player_6_jumping  home_player_6_stamina  home_player_6_strength  \
# 463                     54                     72                      63
# 474                     59                     75                      77
#
#      home_player_6_long_shots  home_player_6_aggression  \
# 463                        78                        61
# 474                        78                        79
#
#      home_player_6_interceptions  home_player_6_positioning  \
# 463                           76                         72
# 474                           72                         70
#
#      home_player_6_vision  home_player_6_penalties  home_player_6_marking  \
# 463                    81                       78                     27
# 474                    69                       74                     67
#
#      home_player_6_standing_tackle  home_player_6_sliding_tackle  \
# 463                             28                            23
# 474                             73                            71
#
#      home_player_6_gk_diving  home_player_6_gk_handling  \
# 463                        6                         22
# 474                        7                         21
#
#      home_player_6_gk_kicking  home_player_6_gk_positioning  \
# 463                        74                            22
# 474                        74                            21
#
#      home_player_6_gk_reflexes  home_player_7_overall_rating  \
# 463                         22                            84
# 474                         21                            73
#
#      home_player_7_potential  home_player_7_preferred_foot  \
# 463                       85                             0
# 474                       78                             1
#
#      home_player_7_attacking_work_rate  home_player_7_defensive_work_rate  \
# 463                                  4                                  8
# 474                                  4                                  8
#
#      home_player_7_crossing  home_player_7_finishing  \
# 463                      88                       70
# 474                      46                       30
#
#      home_player_7_heading_accuracy  home_player_7_short_passing  \
# 463                              74                           88
# 474                              55                           74
#
#      home_player_7_volleys  home_player_7_dribbling  home_player_7_curve  \
# 463                     70                       76                   82
# 474                     34                       66                   53
#
#      home_player_7_free_kick_accuracy  home_player_7_long_passing  \
# 463                                82                          87
# 474                                50                          62
#
#      home_player_7_ball_control  home_player_7_acceleration  \
# 463                          86                          71
# 474                          68                          72
#
#      home_player_7_sprint_speed  home_player_7_agility  \
# 463                          70                     56
# 474                          75                     62
#
#      home_player_7_reactions  home_player_7_balance  home_player_7_shot_power  \
# 463                       79                     79                        81
# 474                       76                     71                        55
#
#      home_player_7_jumping  home_player_7_stamina  home_player_7_strength  \
# 463                     77                     87                      82
# 474                     70                     75                      78
#
#      home_player_7_long_shots  home_player_7_aggression  \
# 463                        84                        84
# 474                        45                        86
#
#      home_player_7_interceptions  home_player_7_positioning  \
# 463                           86                         87
# 474                           69                         74
#
#      home_player_7_vision  home_player_7_penalties  home_player_7_marking  \
# 463                    85                       80                     80
# 474                    62                       55                     75
#
#      home_player_7_standing_tackle  home_player_7_sliding_tackle  \
# 463                             83                            84
# 474                             79                            76
#
#      home_player_7_gk_diving  home_player_7_gk_handling  \
# 463                       12                         22
# 474                        1                         22
#
#      home_player_7_gk_kicking  home_player_7_gk_positioning  \
# 463                        87                            22
# 474                        62                            22
#
#      home_player_7_gk_reflexes  home_player_8_overall_rating  \
# 463                         22                            79
# 474                         22                            71
#
#      home_player_8_potential  home_player_8_preferred_foot  \
# 463                       84                             1
# 474                       86                             1
#
#      home_player_8_attacking_work_rate  home_player_8_defensive_work_rate  \
# 463                                  4                                  7
# 474                                  4                                  9
#
#      home_player_8_crossing  home_player_8_finishing  \
# 463                      72                       56
# 474                      76                       66
#
#      home_player_8_heading_accuracy  home_player_8_short_passing  \
# 463                              76                           83
# 474                              33                           74
#
#      home_player_8_volleys  home_player_8_dribbling  home_player_8_curve  \
# 463                     59                       71                   61
# 474                     61                       83                   64
#
#      home_player_8_free_kick_accuracy  home_player_8_long_passing  \
# 463                                68                          77
# 474                                58                          74
#
#      home_player_8_ball_control  home_player_8_acceleration  \
# 463                          77                          75
# 474                          78                          64
#
#      home_player_8_sprint_speed  home_player_8_agility  \
# 463                          70                     68
# 474                          68                     66
#
#      home_player_8_reactions  home_player_8_balance  home_player_8_shot_power  \
# 463                       79                     78                        73
# 474                       63                     72                        63
#
#      home_player_8_jumping  home_player_8_stamina  home_player_8_strength  \
# 463                     86                     86                      75
# 474                     66                     69                      49
#
#      home_player_8_long_shots  home_player_8_aggression  \
# 463                        72                        80
# 474                        64                        46
#
#      home_player_8_interceptions  home_player_8_positioning  \
# 463                           75                         86
# 474                           54                         69
#
#      home_player_8_vision  home_player_8_penalties  home_player_8_marking  \
# 463                    82                       73                     76
# 474                    74                       74                     22
#
#      home_player_8_standing_tackle  home_player_8_sliding_tackle  \
# 463                             83                            79
# 474                             22                            61
#
#      home_player_8_gk_diving  home_player_8_gk_handling  \
# 463                        6                         21
# 474                        2                         22
#
#      home_player_8_gk_kicking  home_player_8_gk_positioning  \
# 463                        77                            21
# 474                        74                            22
#
#      home_player_8_gk_reflexes  home_player_9_overall_rating  \
# 463                         21                            82
# 474                         22                            72
#
#      home_player_9_potential  home_player_9_preferred_foot  \
# 463                       84                             1
# 474                       77                             1
#
#      home_player_9_attacking_work_rate  home_player_9_defensive_work_rate  \
# 463                                  2                                  8
# 474                                  2                                  8
#
#      home_player_9_crossing  home_player_9_finishing  \
# 463                      78                       86
# 474                      57                       40
#
#      home_player_9_heading_accuracy  home_player_9_short_passing  \
# 463                              67                           76
# 474                              74                           76
#
#      home_player_9_volleys  home_player_9_dribbling  home_player_9_curve  \
# 463                     80                       84                   69
# 474                     42                       62                   40
#
#      home_player_9_free_kick_accuracy  home_player_9_long_passing  \
# 463                                74                          59
# 474                                29                          59
#
#      home_player_9_ball_control  home_player_9_acceleration  \
# 463                          83                          89
# 474                          69                          75
#
#      home_player_9_sprint_speed  home_player_9_agility  \
# 463                          88                     85
# 474                          76                     63
#
#      home_player_9_reactions  home_player_9_balance  home_player_9_shot_power  \
# 463                       88                     86                        83
# 474                       65                     72                        65
#
#      home_player_9_jumping  home_player_9_stamina  home_player_9_strength  \
# 463                     79                     88                      77
# 474                     80                     79                      86
#
#      home_player_9_long_shots  home_player_9_aggression  \
# 463                        78                        90
# 474                        46                        77
#
#      home_player_9_interceptions  home_player_9_positioning  \
# 463                           76                         77
# 474                           76                         73
#
#      home_player_9_vision  home_player_9_penalties  home_player_9_marking  \
# 463                    77                       86                     60
# 474                    62                       60                     69
#
#      home_player_9_standing_tackle  home_player_9_sliding_tackle  \
# 463                             51                            50
# 474                             76                            74
#
#      home_player_9_gk_diving  home_player_9_gk_handling  \
# 463                        5                         22
# 474                        3                         22
#
#      home_player_9_gk_kicking  home_player_9_gk_positioning  \
# 463                        59                            22
# 474                        59                            22
#
#      home_player_9_gk_reflexes  home_player_10_overall_rating  \
# 463                         22                             81
# 474                         22                             77
#
#      home_player_10_potential  home_player_10_preferred_foot  \
# 463                        86                              1
# 474                        80                              1
#
#      home_player_10_attacking_work_rate  home_player_10_defensive_work_rate  \
# 463                                   2                                   9
# 474                                   2                                  10
#
#      home_player_10_crossing  home_player_10_finishing  \
# 463                       78                        83
# 474                       75                        79
#
#      home_player_10_heading_accuracy  home_player_10_short_passing  \
# 463                               66                            79
# 474                               78                            67
#
#      home_player_10_volleys  home_player_10_dribbling  home_player_10_curve  \
# 463                      85                        83                    70
# 474                      76                        78                    68
#
#      home_player_10_free_kick_accuracy  home_player_10_long_passing  \
# 463                                 62                           73
# 474                                 69                           63
#
#      home_player_10_ball_control  home_player_10_acceleration  \
# 463                           84                           83
# 474                           77                           79
#
#      home_player_10_sprint_speed  home_player_10_agility  \
# 463                           78                      81
# 474                           77                      78
#
#      home_player_10_reactions  home_player_10_balance  \
# 463                        84                      74
# 474                        74                      74
#
#      home_player_10_shot_power  home_player_10_jumping  \
# 463                         81                      67
# 474                         78                      80
#
#      home_player_10_stamina  home_player_10_strength  \
# 463                      78                       71
# 474                      72                       75
#
#      home_player_10_long_shots  home_player_10_aggression  \
# 463                         84                         76
# 474                         78                         71
#
#      home_player_10_interceptions  home_player_10_positioning  \
# 463                            76                          80
# 474                            69                          73
#
#      home_player_10_vision  home_player_10_penalties  home_player_10_marking  \
# 463                     87                        77                      70
# 474                     71                        78                      53
#
#      home_player_10_standing_tackle  home_player_10_sliding_tackle  \
# 463                              71                             69
# 474                              55                             35
#
#      home_player_10_gk_diving  home_player_10_gk_handling  \
# 463                        13                          22
# 474                        11                          22
#
#      home_player_10_gk_kicking  home_player_10_gk_positioning  \
# 463                         73                             22
# 474                         63                             22
#
#      home_player_10_gk_reflexes  home_player_11_overall_rating  \
# 463                          22                             86
# 474                          22                             75
#
#      home_player_11_potential  home_player_11_preferred_foot  \
# 463                        90                              1
# 474                        78                              1
#
#      home_player_11_attacking_work_rate  home_player_11_defensive_work_rate  \
# 463                                   2                                   5
# 474                                   2                                   6
#
#      home_player_11_crossing  home_player_11_finishing  \
# 463                       74                        91
# 474                       58                        77
#
#      home_player_11_heading_accuracy  home_player_11_short_passing  \
# 463                               70                            83
# 474                               77                            65
#
#      home_player_11_volleys  home_player_11_dribbling  home_player_11_curve  \
# 463                      88                        83                    77
# 474                      71                        73                    33
#
#      home_player_11_free_kick_accuracy  home_player_11_long_passing  \
# 463                                 82                           64
# 474                                 56                           45
#
#      home_player_11_ball_control  home_player_11_acceleration  \
# 463                           85                           86
# 474                           71                           77
#
#      home_player_11_sprint_speed  home_player_11_agility  \
# 463                           84                      81
# 474                           77                      69
#
#      home_player_11_reactions  home_player_11_balance  \
# 463                        92                      91
# 474                        72                      55
#
#      home_player_11_shot_power  home_player_11_jumping  \
# 463                         88                      72
# 474                         79                      81
#
#      home_player_11_stamina  home_player_11_strength  \
# 463                      91                       85
# 474                      68                       74
#
#      home_player_11_long_shots  home_player_11_aggression  \
# 463                         85                         92
# 474                         71                         49
#
#      home_player_11_interceptions  home_player_11_positioning  \
# 463                            77                          88
# 474                            23                          78
#
#      home_player_11_vision  home_player_11_penalties  home_player_11_marking  \
# 463                     82                        89                      39
# 474                     65                        75                      21
#
#      home_player_11_standing_tackle  home_player_11_sliding_tackle  \
# 463                              33                             34
# 474                              23                             22
#
#      home_player_11_gk_diving  home_player_11_gk_handling  \
# 463                        11                          23
# 474                         7                           7
#
#      home_player_11_gk_kicking  home_player_11_gk_positioning  \
# 463                         64                             23
# 474                          8                             11
#
#      home_player_11_gk_reflexes  away_player_1_overall_rating  \
# 463                          23                            82
# 474                          14                            82
#
#      away_player_1_potential  away_player_1_preferred_foot  \
# 463                       86                             1
# 474                       84                             1
#
#      away_player_1_attacking_work_rate  away_player_1_defensive_work_rate  \
# 463                                  2                                  5
# 474                                  2                                  5
#
#      away_player_1_crossing  away_player_1_finishing  \
# 463                      20                       20
# 474                      23                       23
#
#      away_player_1_heading_accuracy  away_player_1_short_passing  \
# 463                              20                           42
# 474                              23                           24
#
#      away_player_1_volleys  away_player_1_dribbling  away_player_1_curve  \
# 463                     21                       20                    9
# 474                     10                       23                   18
#
#      away_player_1_free_kick_accuracy  away_player_1_long_passing  \
# 463                                 9                          75
# 474                                19                          82
#
#      away_player_1_ball_control  away_player_1_acceleration  \
# 463                          20                          53
# 474                          22                          32
#
#      away_player_1_sprint_speed  away_player_1_agility  \
# 463                          48                     48
# 474                          53                     45
#
#      away_player_1_reactions  away_player_1_balance  away_player_1_shot_power  \
# 463                       78                     79                        25
# 474                       69                     58                        22
#
#      away_player_1_jumping  away_player_1_stamina  away_player_1_strength  \
# 463                     75                     63                      70
# 474                     50                     65                      74
#
#      away_player_1_long_shots  away_player_1_aggression  \
# 463                        20                        45
# 474                        23                        63
#
#      away_player_1_interceptions  away_player_1_positioning  \
# 463                           61                         51
# 474                           65                         64
#
#      away_player_1_vision  away_player_1_penalties  away_player_1_marking  \
# 463                    66                       58                     20
# 474                    63                       67                     23
#
#      away_player_1_standing_tackle  away_player_1_sliding_tackle  \
# 463                             20                             9
# 474                             23                            11
#
#      away_player_1_gk_diving  away_player_1_gk_handling  \
# 463                       81                         82
# 474                       82                         86
#
#      away_player_1_gk_kicking  away_player_1_gk_positioning  \
# 463                        75                            81
# 474                        82                            86
#
#      away_player_1_gk_reflexes  away_player_2_overall_rating  \
# 463                         87                            78
# 474                         81                            78
#
#      away_player_2_potential  away_player_2_preferred_foot  \
# 463                       79                             1
# 474                       84                             1
#
#      away_player_2_attacking_work_rate  away_player_2_defensive_work_rate  \
# 463                                  4                                  8
# 474                                  3                                  8
#
#      away_player_2_crossing  away_player_2_finishing  \
# 463                      76                       36
# 474                      60                       22
#
#      away_player_2_heading_accuracy  away_player_2_short_passing  \
# 463                              69                           82
# 474                              87                           64
#
#      away_player_2_volleys  away_player_2_dribbling  away_player_2_curve  \
# 463                     63                       53                   45
# 474                     44                       51                   61
#
#      away_player_2_free_kick_accuracy  away_player_2_long_passing  \
# 463                                41                          77
# 474                                26                          54
#
#      away_player_2_ball_control  away_player_2_acceleration  \
# 463                          73                          72
# 474                          65                          70
#
#      away_player_2_sprint_speed  away_player_2_agility  \
# 463                          77                     62
# 474                          73                     62
#
#      away_player_2_reactions  away_player_2_balance  away_player_2_shot_power  \
# 463                       84                     76                        77
# 474                       70                     77                        43
#
#      away_player_2_jumping  away_player_2_stamina  away_player_2_strength  \
# 463                     71                     84                      78
# 474                     85                     72                      88
#
#      away_player_2_long_shots  away_player_2_aggression  \
# 463                        64                        80
# 474                        21                        84
#
#      away_player_2_interceptions  away_player_2_positioning  \
# 463                           83                         84
# 474                           74                         77
#
#      away_player_2_vision  away_player_2_penalties  away_player_2_marking  \
# 463                    77                       77                     80
# 474                    64                       67                     76
#
#      away_player_2_standing_tackle  away_player_2_sliding_tackle  \
# 463                             77                            72
# 474                             77                            77
#
#      away_player_2_gk_diving  away_player_2_gk_handling  \
# 463                       14                         21
# 474                        7                         24
#
#      away_player_2_gk_kicking  away_player_2_gk_positioning  \
# 463                        77                            21
# 474                        54                            24
#
#      away_player_2_gk_reflexes  away_player_3_overall_rating  \
# 463                         21                            79
# 474                         24                            78
#
#      away_player_3_potential  away_player_3_preferred_foot  \
# 463                       86                             1
# 474                       82                             1
#
#      away_player_3_attacking_work_rate  away_player_3_defensive_work_rate  \
# 463                                  4                                 12
# 474                                  4                                 12
#
#      away_player_3_crossing  away_player_3_finishing  \
# 463                      66                       30
# 474                      38                       48
#
#      away_player_3_heading_accuracy  away_player_3_short_passing  \
# 463                              80                           74
# 474                              78                           60
#
#      away_player_3_volleys  away_player_3_dribbling  away_player_3_curve  \
# 463                     63                       51                   60
# 474                     24                       56                   29
#
#      away_player_3_free_kick_accuracy  away_player_3_long_passing  \
# 463                                31                          70
# 474                                71                          53
#
#      away_player_3_ball_control  away_player_3_acceleration  \
# 463                          74                          72
# 474                          57                          70
#
#      away_player_3_sprint_speed  away_player_3_agility  \
# 463                          73                     49
# 474                          74                     44
#
#      away_player_3_reactions  away_player_3_balance  away_player_3_shot_power  \
# 463                       72                     74                        69
# 474                       72                     68                        75
#
#      away_player_3_jumping  away_player_3_stamina  away_player_3_strength  \
# 463                     77                     69                      79
# 474                     88                     74                      85
#
#      away_player_3_long_shots  away_player_3_aggression  \
# 463                        54                        77
# 474                        39                        80
#
#      away_player_3_interceptions  away_player_3_positioning  \
# 463                           81                         85
# 474                           73                         68
#
#      away_player_3_vision  away_player_3_penalties  away_player_3_marking  \
# ...
# 474                    84                       85                     74
#
#      away_player_8_standing_tackle  away_player_8_sliding_tackle  \
# 463                             63                            66
# 474                             77                            69
#
#      away_player_8_gk_diving  away_player_8_gk_handling  \
# 463                       12                         25
# 474                       13                         21
#
#      away_player_8_gk_kicking  away_player_8_gk_positioning  \
# 463                        81                            25
# 474                        83                            21
#
#      away_player_8_gk_reflexes  away_player_9_overall_rating  \
# 463                         25                            80
# 474                         21                            81
#
#      away_player_9_potential  away_player_9_preferred_foot  \
# 463                       80                             1
# 474                       85                             0
#
#      away_player_9_attacking_work_rate  away_player_9_defensive_work_rate  \
# 463                                  2                                 10
# 474                                  4                                 10
#
#      away_player_9_crossing  away_player_9_finishing  \
# 463                      79                       67
# 474                      87                       73
#
#      away_player_9_heading_accuracy  away_player_9_short_passing  \
# 463                              58                           79
# 474                              71                           79
#
#      away_player_9_volleys  away_player_9_dribbling  away_player_9_curve  \
# 463                     72                       83                   74
# 474                     82                       84                   81
#
#      away_player_9_free_kick_accuracy  away_player_9_long_passing  \
# 463                                76                          72
# 474                                86                          74
#
#      away_player_9_ball_control  away_player_9_acceleration  \
# 463                          87                          83
# 474                          82                          82
#
#      away_player_9_sprint_speed  away_player_9_agility  \
# 463                          76                     86
# 474                          80                     78
#
#      away_player_9_reactions  away_player_9_balance  away_player_9_shot_power  \
# 463                       79                     74                        76
# 474                       79                     77                        75
#
#      away_player_9_jumping  away_player_9_stamina  away_player_9_strength  \
# 463                     60                     78                      64
# 474                     58                     77                      68
#
#      away_player_9_long_shots  away_player_9_aggression  \
# 463                        70                        76
# 474                        74                        48
#
#      away_player_9_interceptions  away_player_9_positioning  \
# 463                           76                         75
# 474                           69                         79
#
#      away_player_9_vision  away_player_9_penalties  away_player_9_marking  \
# 463                    77                       88                     50
# 474                    82                       77                     37
#
#      away_player_9_standing_tackle  away_player_9_sliding_tackle  \
# 463                             38                            35
# 474                             38                            36
#
#      away_player_9_gk_diving  away_player_9_gk_handling  \
# 463                        1                         20
# 474                       10                         21
#
#      away_player_9_gk_kicking  away_player_9_gk_positioning  \
# 463                        72                            20
# 474                        74                            21
#
#      away_player_9_gk_reflexes  away_player_10_overall_rating  \
# 463                         20                             79
# 474                         21                             81
#
#      away_player_10_potential  away_player_10_preferred_foot  \
# 463                        85                              1
# 474                        85                              1
#
#      away_player_10_attacking_work_rate  away_player_10_defensive_work_rate  \
# 463                                   2                                  11
# 474                                   5                                  11
#
#      away_player_10_crossing  away_player_10_finishing  \
# 463                       79                        79
# 474                       61                        80
#
#      away_player_10_heading_accuracy  away_player_10_short_passing  \
# 463                               91                            78
# 474                               92                            75
#
#      away_player_10_volleys  away_player_10_dribbling  away_player_10_curve  \
# 463                      84                        76                    66
# 474                      78                        79                    74
#
#      away_player_10_free_kick_accuracy  away_player_10_long_passing  \
# 463                                 69                           75
# 474                                 60                           41
#
#      away_player_10_ball_control  away_player_10_acceleration  \
# 463                           80                           76
# 474                           81                           83
#
#      away_player_10_sprint_speed  away_player_10_agility  \
# 463                           77                      70
# 474                           84                      67
#
#      away_player_10_reactions  away_player_10_balance  \
# 463                        85                      83
# 474                        76                      90
#
#      away_player_10_shot_power  away_player_10_jumping  \
# 463                         81                      94
# 474                         86                      91
#
#      away_player_10_stamina  away_player_10_strength  \
# 463                      81                       80
# 474                      70                       89
#
#      away_player_10_long_shots  away_player_10_aggression  \
# 463                         78                         87
# 474                         69                         77
#
#      away_player_10_interceptions  away_player_10_positioning  \
# 463                            81                          84
# 474                            76                          85
#
#      away_player_10_vision  away_player_10_penalties  away_player_10_marking  \
# 463                     77                        83                      74
# 474                     72                        82                      22
#
#      away_player_10_standing_tackle  away_player_10_sliding_tackle  \
# 463                              73                             73
# 474                              30                             16
#
#      away_player_10_gk_diving  away_player_10_gk_handling  \
# 463                         5                          20
# 474                         5                          22
#
#      away_player_10_gk_kicking  away_player_10_gk_positioning  \
# 463                         75                             20
# 474                         41                             22
#
#      away_player_10_gk_reflexes  away_player_11_overall_rating  \
# 463                          20                             83
# 474                          22                             83
#
#      away_player_11_potential  away_player_11_preferred_foot  \
# 463                        86                              0
# 474                        87                              1
#
#      away_player_11_attacking_work_rate  away_player_11_defensive_work_rate  \
# 463                                   4                                   7
# 474                                   4                                   6
#
#      away_player_11_crossing  away_player_11_finishing  \
# 463                       60                        86
# 474                       73                        85
#
#      away_player_11_heading_accuracy  away_player_11_short_passing  \
# 463                               82                            73
# 474                               78                            72
#
#      away_player_11_volleys  away_player_11_dribbling  away_player_11_curve  \
# 463                      79                        80                    75
# 474                      80                        83                    61
#
#      away_player_11_free_kick_accuracy  away_player_11_long_passing  \
# 463                                 60                           41
# 474                                 50                           52
#
#      away_player_11_ball_control  away_player_11_acceleration  \
# 463                           84                           85
# 474                           80                           95
#
#      away_player_11_sprint_speed  away_player_11_agility  \
# 463                           84                      85
# 474                           93                      79
#
#      away_player_11_reactions  away_player_11_balance  \
# 463                        86                      78
# 474                        84                      84
#
#      away_player_11_shot_power  away_player_11_jumping  \
# 463                         85                      86
# 474                         79                      70
#
#      away_player_11_stamina  away_player_11_strength  \
# 463                      72                       77
# 474                      83                       82
#
#      away_player_11_long_shots  away_player_11_aggression  \
# 463                         87                         59
# 474                         75                         63
#
#      away_player_11_interceptions  away_player_11_positioning  \
# 463                            81                          88
# 474                            76                          78
#
#      away_player_11_vision  away_player_11_penalties  away_player_11_marking  \
# 463                     77                        88                      38
# 474                     68                        70                      34
#
#      away_player_11_standing_tackle  away_player_11_sliding_tackle  \
# 463                              41                             42
# 474                              40                             44
#
#      away_player_11_gk_diving  away_player_11_gk_handling  \
# 463                         5                          21
# 474                         9                          21
#
#      away_player_11_gk_kicking  away_player_11_gk_positioning  \
# 463                         41                             21
# 474                         52                             21
#
#      away_player_11_gk_reflexes  outcome  home_team_goals_difference  \
# 463                          21       -1                           7
# 474                          21       -1                          -7
#
#      away_team_goals_difference  games_won_home_team  games_won_away_team  \
# 463                          12                    5                    7
# 474                           2                    2                    3
#
#      games_against_won_home  games_against_lost_home  home_buildUpPlaySpeed  \
# 463                       1                        2                   70.0
# 474                       1                        1                   70.0
#
#      away_buildUpPlaySpeed  home_buildUpPlaySpeedClass  \
# 463                      2                           1
# 474                      2                           1
#
#      away_buildUpPlaySpeedClass  home_buildUpPlayDribblingClass  \
# 463                        60.0                               2
# 474                        70.0                               1
#
#      away_buildUpPlayDribblingClass  home_buildUpPlayPassing  \
# 463                               2                     55.0
# 474                               2                     70.0
#
#      away_buildUpPlayPassing  home_buildUpPlayPassingClass  \
# 463                        1                          70.0
# 474                        2                          70.0
#
#      away_buildUpPlayPassingClass  home_buildUpPlayPositioningClass  \
# 463                             2                              70.0
# 474                             2                              50.0
#
#      away_buildUpPlayPositioningClass  home_chanceCreationPassing  \
# 463                                 2                           2
# 474                                 3                           2
#
#      away_chanceCreationPassing  home_chanceCreationPassingClass  \
# 463                        45.0                                3
# 474                        35.0                                3
#
#      away_chanceCreationPassingClass  home_chanceCreationCrossing  \
# 463                             55.0                            3
# 474                             70.0                            2
#
#      away_chanceCreationCrossing  home_chanceCreationCrossingClass  \
# 463                         45.0                                 2
# 474                         35.0                                 2
#
#      away_chanceCreationCrossingClass  home_chanceCreationShooting  \
# 463                                 1                         60.0
# 474                                 1                         70.0
#
#      away_chanceCreationShooting  home_chanceCreationShootingClass  \
# 463                            1                                 1
# 474                            2                                 1
#
#      away_chanceCreationShootingClass  home_chanceCreationPositioningClass  \
# 463                              65.0                                    2
# 474                              59.0                                    2
#
#      away_chanceCreationPositioningClass  home_defencePressure  \
# 463                                    2                  60.0
# 474                                    2                  65.0
#
#      away_defencePressure  home_defencePressureClass  \
# 463                     1                       70.0
# 474                     1                       70.0
#
#      away_defencePressureClass  home_defenceAggression  \
# 463                          2                    45.0
# 474                          2                    50.0
#
#      away_defenceAggression  home_defenceAggressionClass  \
# 463                       3                            2
# 474                       3                            1
#
#      away_defenceAggressionClass  home_defenceTeamWidth  \
# 463                         40.0                      3
# 474                         30.0                      1
#
#      away_defenceTeamWidth  home_defenceTeamWidthClass  \
# 463                   70.0                           2
# 474                   70.0                           2
#
#      away_defenceTeamWidthClass  home_defenceDefenderLineClass  \
# 463                        40.0                              2
# 474                        30.0                              1
#
#      away_defenceDefenderLineClass  home_form  away_form  year  month  dow  \
# 463                              1          3          3  2010      3    2
# 474                              1          0         31  2010      3    1
#
#      hour
# 463      0
# 474      0

# %%
# don't need id and date column

data_final.drop(['date'], axis=1, inplace=True)

# %%
data_final.drop(['home_team_goal', 'away_team_goal'], axis=1, inplace=True)

# %% [markdown]
# Making lineup of home and way players

# %%
# data_final['away_lineup'] = data_final[['away_player_X1', 'away_player_X2', 'away_player_X3', 'away_player_X4',
#        'away_player_X5', 'away_player_X6', 'away_player_X7', 'away_player_X8',
#        'away_player_X9', 'away_player_X10', 'away_player_X11', 'away_player_Y1', 'away_player_Y2', 'away_player_Y3', 'away_player_Y4',
#        'away_player_Y5', 'away_player_Y6', 'away_player_Y7', 'away_player_Y8',
#        'away_player_Y9', 'away_player_Y10', 'away_player_Y11']].astype(str).add('_').sum(axis=1).str[:-1]

# %%
# data_final['home_lineup'] = data_final[['home_player_X1', 'home_player_X2', 'home_player_X3', 'home_player_X4',
#        'home_player_X5', 'home_player_X6', 'home_player_X7', 'home_player_X8',
#        'home_player_X9', 'home_player_X10', 'home_player_X11', 'home_player_Y1', 'home_player_Y2', 'home_player_Y3', 'home_player_Y4',
#        'home_player_Y5', 'home_player_Y6', 'home_player_Y7', 'home_player_Y8',
#        'home_player_Y9', 'home_player_Y10', 'home_player_Y11']].astype(str).add('_').sum(axis=1).str[:-1]

# %%
data_final.shape
# Out:
# (6560, 895)

# %%
id_cols_to_rem = list(data_final.filter(regex='id$').columns) + list(data_final.filter(regex='\d$').columns)

# %%
id_cols_to_rem
# Out:
# ['match_api_id', 'home_team_api_id', 'away_team_api_id']

# %%
match_team_id = data_final[id_cols_to_rem]

# %%
data_final.drop(id_cols_to_rem, axis=1, inplace=True)

# %%
# new cols were string
convert_cats(data_final)

# %% [markdown]
# ### Splitting data into train, validation and test

# %%
train = data_final[(data_final.year != 2016) & (data_final.year != 2015) &
                   (data_final.year != 2014)]
val1 = data_final[data_final.year == 2014]
train_val1 = data_final[(data_final.year != 2016) & (data_final.year != 2015)]
val2 = data_final[data_final.year == 2015]

# completely hold out
test = data_final[data_final.year == 2016]

# %%
train.shape, val1.shape, train_val1.shape, val2.shape, test.shape
# Out:
# ((3938, 892), (1038, 892), (4976, 892), (1051, 892), (533, 892))

# %%
x_train, y_train = train.drop('outcome', axis=1), train['outcome']
x_val1, y_val1 = val1.drop('outcome', axis=1), val1['outcome']
x_val2, y_val2 = val2.drop('outcome', axis=1), val2['outcome']
x_test, y_test = test.drop('outcome', axis=1), test['outcome']

# %% [markdown]
# ### Random Forest

# %% [markdown]
# Multiclass without callibration

# %%
m = RandomForestClassifier(n_jobs=-1, n_estimators=200, random_state=10)
m.fit(train_val1.drop('outcome', axis=1), train_val1['outcome'])
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=200, n_jobs=-1,
#             oob_score=False, random_state=10, verbose=0, warm_start=False)

# %%
m_probs = m.predict_proba(val2.drop('outcome', axis=1))
score = log_loss(val2['outcome'], m_probs)
score
# Out:
# 1.0077618242724922

# %%
m_probs[:10]
# Out:
# array([[0.28 , 0.305, 0.415],
#        [0.425, 0.33 , 0.245],
#        [0.16 , 0.26 , 0.58 ],
#        [0.095, 0.12 , 0.785],
#        [0.315, 0.225, 0.46 ],
#        [0.235, 0.315, 0.45 ],
#        [0.465, 0.25 , 0.285],
#        [0.4  , 0.33 , 0.27 ],
#        [0.555, 0.28 , 0.165],
#        [0.25 , 0.29 , 0.46 ]])

# %%
m.score(val2.drop('outcome', axis=1), val2['outcome'])
# Out:
# 0.5014272121788773

# %% [markdown]
# Multiclass with callibration

# %%
m2 = RandomForestClassifier(n_estimators=200, n_jobs=-1, random_state=10)
m2.fit(train.drop('outcome', axis=1), train['outcome'])
m2_probs = m2.predict_proba(val1.drop('outcome', axis=1))

sig_m2 = CalibratedClassifierCV(m2, method="sigmoid", cv="prefit")
sig_m2.fit(val1.drop('outcome', axis=1),
           val1['outcome'])  # final callibrated model
sig_m2_probs = sig_m2.predict_proba(val2.drop('outcome', axis=1))
sig_score = log_loss(val2['outcome'], sig_m2_probs)

print('logloss : ', sig_score)
# Out:
# logloss :  1.000009719575398

# %%
sig_m2.score(x_val2, y_val2)
# Out:
# 0.5033301617507137

# %% [markdown]
# #### Hyperparameter tuning

# %%
def fitOne(model, x_train, y_train, x_val1, y_val1, params):

    model.set_params(**params)
    m = model.fit(x_train, y_train)

    sig_mod = CalibratedClassifierCV(m, method="sigmoid", cv="prefit")
    return sig_mod.fit(x_val1, y_val1)


def fitModels(model,
              paramGrid,
              x_train,
              y_train,
              x_val1,
              y_val1,
              n_jobs=-1,
              verbose=10):

    return Parallel(
        n_jobs=n_jobs, verbose=verbose)(
            delayed(fitOne)(model, x_train, y_train, x_val1, y_val1, params)
            for params in paramGrid)


def scoreOne(model, x, y, metric):
    probs = model.predict_proba(x)
    return log_loss(y, probs)


def scoreModels(models,
                X,
                y,
                metric=log_loss,
                predict_proba=True,
                n_jobs=-1,
                verbose=10):

    return Parallel(
        n_jobs=n_jobs, verbose=np.ceil(verbose / 10))(
            delayed(scoreOne)(m, X, y, metric) for m in models)


def getBestModel(models, scores, greater_is_better=False):

    if greater_is_better:
        return models[np.argmax(scores)]
    else:
        return models[np.argmin(scores)]


def getBestScore(scores, greater_is_better=False):

    if greater_is_better:
        return np.max(scores)
    else:
        return np.min(scores)


def bestFit(model,
            paramGrid,
            x_train,
            y_train,
            x_val1,
            y_val1,
            x_val2,
            y_val2,
            metric=log_loss,
            greater_is_better=False,
            predict_proba=True,
            scoreLabel=None,
            vrange=None,
            cmap='YlOrRd',
            n_jobs=-1,
            verbose=10):
    print('-------------FITTING MODELS-------------')
    models = fitModels(model, paramGrid, x_train, y_train, x_val1, y_val1,
                       n_jobs, verbose)
    print('-------------SCORING MODELS-------------')
    scores = scoreModels(models, x_val2, y_val2, metric, predict_proba, n_jobs,
                         verbose)

    return getBestModel(models, scores, greater_is_better), getBestScore(
        scores, greater_is_better), models, scores

# %%
grid = {
    'min_samples_leaf': [1, 5, 10, 15, 20, 25],
    'max_features': ['sqrt', 'log2', 0.5],
    'n_estimators': [100],
    'n_jobs': [-1],
    'random_state': [10]
}
paramGrid = ParameterGrid(grid)

# %%
best_model, best_score, all_models, all_scores = bestFit(RandomForestClassifier(), paramGrid,
                                                    x_train, y_train, x_val1, y_val1, x_val2, y_val2,
                                                    metric=roc_auc_score, greater_is_better=False, 
                                                    scoreLabel='log_loss')
# Out:
# -------------FITTING MODELS-------------
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    9.5s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:   11.5s
# [Parallel(n_jobs=-1)]: Done  13 out of  18 | elapsed:  1.3min remaining:   29.5s
# [Parallel(n_jobs=-1)]: Done  15 out of  18 | elapsed:  1.7min remaining:   20.0s
# -------------SCORING MODELS-------------
# [Parallel(n_jobs=-1)]: Done  18 out of  18 | elapsed:  2.1min finished
# [Parallel(n_jobs=-1)]: Done  18 out of  18 | elapsed:    1.3s finished

# %%
best_score
# Out:
# 0.9896570297571913

# %%
best_model
# Out:
# CalibratedClassifierCV(base_estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='log2', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=25, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#             oob_score=False, random_state=10, verbose=0, warm_start=False),
#             cv='prefit', method='sigmoid')

# %%
best_model = RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
            max_depth=None, max_features='log2', max_leaf_nodes=None,
            min_impurity_decrease=0.0, min_impurity_split=None,
            min_samples_leaf=25, min_samples_split=2,
            min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
            oob_score=False, random_state=10, verbose=0, warm_start=False)

best_model.fit(pd.DataFrame(pd.concat((x_train, x_val1))), pd.DataFrame(pd.concat((y_train, y_val1))))
# probs = best_model.predict_proba(x_val1)

sig_m2 = CalibratedClassifierCV(best_model, method="sigmoid", cv="prefit")
sig_m2.fit(x_val2,
           y_val2)  # final callibrated model
sig_m2_probs = sig_m2.predict_proba(x_test)
sig_score = log_loss(y_test, sig_m2_probs)

print('logloss : ', sig_score)
# Out:
# /Users/princegrover/anaconda3/envs/fastai/lib/python3.6/site-packages/ipykernel_launcher.py:8: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# logloss :  0.9849462493182051

# %%
best_model.score(x_test, y_test)
# Out:
# 0.5196998123827392

# %% [markdown]
# #### Feature importance

# %%
# imp = rfpimp.importances(best_model, x_val2 , y_val2) # permutation

# %%
imp

# %%
rfpimp.plot_importances(imp[-50:])

# %%
imp2 = rfpimp.importances(m, x_val2 , y_val2) # permutation

# %%
rfpimp.plot_importances(imp2[-15:])

# %% [markdown]
# ### Predictions and scenario generation

# %%
sig_m2_probs
# Out:
# array([[0.12717311, 0.19970025, 0.67312664],
#        [0.56735644, 0.24303037, 0.18961319],
#        [0.33766726, 0.25718487, 0.40514787],
#        ...,
#        [0.21461691, 0.25105094, 0.53433215],
#        [0.14972794, 0.1817829 , 0.66848916],
#        [0.2677584 , 0.26345347, 0.46878813]])

# %%
plt.hist(sig_m2_probs[:,2])
# Out:
# (array([ 25.,  28.,  36.,  69., 105.,  98.,  71.,  47.,  38.,  16.]),
#  array([0.10111396, 0.17329506, 0.24547615, 0.31765724, 0.38983834,
#         0.46201943, 0.53420052, 0.60638162, 0.67856271, 0.75074381,
#         0.8229249 ]),
#  <a list of 10 Patch objects>)

# %%
sig_m2.classes_
# Out:
# array([-1,  0,  1], dtype=int8)

# %%
bookkeeper_data_keep = bookkeeper_data[['B365H', 'B365D', 'B365A',
                                             'BWH', 'BWD', 'BWA',
                                             'IWH', 'IWD', 'IWA', 'match_api_id']]

# %%
bookkeeper_data_keep[:2]
# Out:
#    B365H  B365D  B365A   BWH   BWD    BWA  IWH  IWD   IWA  match_api_id
# 0   1.29    5.5   11.0  1.30  4.75   8.25  1.3  4.4   8.5        489042
# 1   1.20    6.5   15.0  1.22  5.50  10.00  1.2  5.2  11.0        489043

# %%
match_team_id_test = match_team_id.filter(items=list(x_test.index), axis=0)

# %%
match_team_id_test.reset_index(inplace=True, drop=True)

# %%
match_team_id_test[:2]
# Out:
#    match_api_id  home_team_api_id  away_team_api_id
# 0       1988900              9825             10261
# 1       1988901              9826              8455

# %%
pred_df = pd.DataFrame(sig_m2_probs)
pred_df.columns = ['away', 'draw', 'home']
pred_df_id = pd.DataFrame(pd.concat((match_team_id_test, pred_df), axis=1))

# %%
pred_df_id[:2]
# Out:
#    match_api_id  home_team_api_id  away_team_api_id      away     draw  \
# 0       1988900              9825             10261  0.127173  0.19970
# 1       1988901              9826              8455  0.567356  0.24303
#
#        home
# 0  0.673127
# 1  0.189613

# %%
pred_df_id_bk = pred_df_id.merge(bookkeeper_data_keep, on='match_api_id', how='left')

# %%
pred_df_id_bk['home_odds'] = 1.0/pred_df_id_bk['home']
pred_df_id_bk['draw_odds'] = 1.0/pred_df_id_bk['draw']
pred_df_id_bk['away_odds'] = 1.0/pred_df_id_bk['away']

# %%
outcomes = pd.DataFrame(y_test).reset_index(drop=True)

# %%
pred_df_id_bk = pd.concat((pred_df_id_bk, outcomes), axis=1)

# %%
pred_df_id_bk.shape
# Out:
# (533, 19)

# %%
pred_df_id_bk[:1]
# Out:
#    match_api_id  home_team_api_id  away_team_api_id      away    draw  \
# 0       1988900              9825             10261  0.127173  0.1997
#
#        home  B365H  B365D  B365A   BWH  BWD   BWA  IWH  IWD  IWA  home_odds  \
# 0  0.673127   1.29    6.5   11.0  1.28  5.5  11.0  1.3  5.0  9.0   1.485605
#
#    draw_odds  away_odds  outcome
# 0   5.007505   7.863297        1

# %%
team_data.drop
# Out:
#    id  team_api_id  team_fifa_api_id team_long_name team_short_name
# 0   1         9987             673.0       KRC Genk             GEN
# 1   2         9993             675.0   Beerschot AC             BAC

# %%
pred_df_id_bk = pred_df_id_bk.merge(team_data, left_on='home_team_api_id', right_on='team_api_id').\
                rename(columns={'team_long_name':'home_team_name'}).\
                drop('team_api_id', axis=1)

# %%
pred_df_id_bk = pred_df_id_bk.merge(team_data, left_on='away_team_api_id', right_on='team_api_id').\
                rename(columns={'team_long_name':'away_team_name'}).\
                drop('team_api_id', axis=1)

# %%
pred_df_id_bk[:2]
# Out:
#    match_api_id  home_team_api_id  away_team_api_id      away     draw  \
# 0       1988900              9825             10261  0.127173  0.19970
# 1       1988949              8668             10261  0.150263  0.23606
#
#        home  B365H  B365D  B365A   BWH  BWD    BWA   IWH  IWD  IWA  home_odds  \
# 0  0.673127   1.29    6.5   11.0  1.28  5.5  11.00  1.30  5.0  9.0   1.485605
# 1  0.613677   1.65    4.2    5.5  1.67  3.5   5.25  1.65  3.7  4.9   1.629523
#
#    draw_odds  away_odds  outcome home_team_name    away_team_name
# 0   5.007505   7.863297        1        Arsenal  Newcastle United
# 1   4.236211   6.654980        1        Everton  Newcastle United

# %%
pred_df_id_bk['home_diff_odds'] = pred_df_id_bk[['B365H', 'BWH', 'IWH']].max(axis=1) - \
                                  pred_df_id_bk.home_odds

# %%
pred_df_id_bk['away_diff_odds'] = pred_df_id_bk[['B365A', 'BWA', 'IWA']].max(axis=1) - \
                                  pred_df_id_bk.away_odds

# %%
pred_df_id_bk[(pred_df_id_bk.home > 0.6) &
              (pred_df_id_bk.home_diff_odds>0)].sort_values('home_diff_odds', ascending=False)[:20]
# Out:
#      match_api_id  home_team_api_id  away_team_api_id      away      draw  \
# 209       2002490              8721             10269  0.174256  0.182892
# 36        1987598              8455              8197  0.133369  0.160157
# 521       2030520             10205              9783  0.164780  0.229185
# 337       2002346              8721              9905  0.190549  0.192318
# 183       1988952              8455             10260  0.181247  0.183042
# 512       2030392             10205              9864  0.154746  0.181420
# 419       2030509             10267             10205  0.181647  0.199436
# 32        1989063             10260              8197  0.171835  0.220834
# 29        1989078              8586              8466  0.182168  0.196468
# 30        1988960              9825              8197  0.112018  0.179186
# 251       2002426              8721              8406  0.150279  0.202599
# 373       2030536              9906              9910  0.149728  0.181783
# 20        1988940              9825              8466  0.141830  0.198072
# 213       2002301             10189              9790  0.168944  0.215079
# 38        1988919              8586              8197  0.153813  0.188720
# 362       2030412              8633              9906  0.198974  0.165134
# 460       2030395             10267              8558  0.173132  0.212466
# 398       2030362              8315              8372  0.153540  0.176801
# 261       2002258              8721              8722  0.132635  0.160035
# 303       2002274              8721              8234  0.150142  0.204358
#
#          home  B365H  B365D  B365A   BWH  BWD   BWA   IWH   IWD  IWA  \
# 209  0.642852   2.30   4.00   2.75  2.35  3.8  2.60  2.50  3.50  2.5
# 36   0.706473   2.30   3.75   3.10  2.25  3.6  2.90  2.10  3.30  3.3
# 521  0.606035   2.45   3.10   3.10  2.40  3.1  3.00  2.30  3.30  2.9
# 337  0.617133   2.20   3.40   3.25  2.05  3.5  3.40  2.30  3.30  2.9
# 183  0.635711   2.15   3.30   3.90  2.10  3.2  3.90  2.20  3.30  3.1
# 512  0.663834   2.05   3.30   3.80  2.10  3.3  3.70  1.90  3.45  3.8
# 419  0.618917   2.20   3.30   3.40  2.15  3.4  3.40  2.00  3.30  3.6
# 32   0.607330   2.10   3.40   3.90  2.10  3.4  3.60  1.90  3.45  3.8
# 29   0.621364   2.05   3.60   3.90  1.91  3.6  3.70  1.90  3.45  3.8
# 30   0.708796   1.75   4.00   5.00  1.75  4.0  4.33  1.80  3.50  4.2
# 251  0.647122   1.80   3.75   4.33  1.75  3.7  4.40  1.90  3.45  3.8
# 373  0.668489   1.75   3.75   4.50  1.83  3.6  4.10  1.85  3.70  3.7
# 20   0.660098   1.75   3.75   5.25  1.80  3.5  4.75  1.75  3.50  4.5
# 213  0.615977   1.85   3.60   4.33  1.83  3.5  4.25  1.90  3.45  3.8
# 38   0.657467   1.75   3.80   5.25  1.75  3.8  4.60  1.75  3.50  4.5
# 362  0.635891   1.73   3.60   5.25  1.80  3.5  4.75  1.80  3.50  4.2
# 460  0.614401   1.75   3.60   5.00  1.78  3.6  4.75  1.85  3.45  4.0
# 398  0.669659   1.67   3.75   5.50  1.70  3.5  5.00  1.65  3.60  5.1
# 261  0.707330   1.57   4.00   5.75  1.62  4.0  5.50  1.60  3.90  5.0
# 303  0.645500   1.73   3.60   5.25  1.75  3.7  4.75  1.70  3.60  4.7
#
#      home_odds  draw_odds  away_odds  outcome           home_team_name  \
# 209   1.555568   5.467715   5.738682        1            VfL Wolfsburg
# 36    1.415481   6.243869   7.497967        0                  Chelsea
# 521   1.650071   4.363280   6.068695       -1            Villarreal CF
# 337   1.620396   5.199716   5.247999        0            VfL Wolfsburg
# 183   1.573043   5.463227   5.517318        0                  Chelsea
# 512   1.506401   5.512074   6.462189        1            Villarreal CF
# 419   1.615725   5.014149   5.505182       -1              Valencia CF
# 32    1.646550   4.528279   5.819532        0        Manchester United
# 29    1.609364   5.089882   5.489433       -1        Tottenham Hotspur
# 30    1.410844   5.580779   8.927154        1                  Arsenal
# 251   1.545303   4.935856   6.654302       -1            VfL Wolfsburg
# 373   1.495911   5.501067   6.678780        1          Atlético Madrid
# 20    1.514926   5.048675   7.050685        0                  Arsenal
# 213   1.623437   4.649456   5.919117        1            FC Schalke 04
# 38    1.520990   5.298851   6.501388       -1        Tottenham Hotspur
# 362   1.572596   6.055675   5.025772       -1           Real Madrid CF
# 460   1.627601   4.706631   5.775925        1              Valencia CF
# 398   1.493297   5.656091   6.512953        1  Athletic Club de Bilbao
# 261   1.413768   6.248614   7.539507        0            VfL Wolfsburg
# 303   1.549188   4.893363   6.660362        1            VfL Wolfsburg
#
#                 away_team_name  home_diff_odds  away_diff_odds
# 209              VfB Stuttgart        0.944432       -2.988682
# 36              Leicester City        0.884519       -4.197967
# 521  RC Deportivo de La Coruña        0.799929       -2.968695
# 337            1. FSV Mainz 05        0.679604       -1.847999
# 183          Manchester United        0.626957       -1.617318
# 512                  Málaga CF        0.593599       -2.662189
# 419              Villarreal CF        0.584275       -1.905182
# 32              Leicester City        0.453450       -1.919532
# 29                 Southampton        0.440636       -1.589433
# 30              Leicester City        0.389156       -3.927154
# 251                FC Augsburg        0.354697       -2.254302
# 373           RC Celta de Vigo        0.354089       -2.178780
# 20                 Southampton        0.285074       -1.800685
# 213               Hamburger SV        0.276563       -1.589117
# 38              Leicester City        0.229010       -1.251388
# 362            Atlético Madrid        0.227404        0.224228
# 460               RCD Espanyol        0.222399       -0.775925
# 398                   SD Eibar        0.206703       -1.012953
# 261                 1. FC Köln        0.206232       -1.789507
# 303           FC Ingolstadt 04        0.200812       -1.410362

# %%
pred_df_id_bk[(pred_df_id_bk.away > 0.5) & (pred_df_id_bk.away_diff_odds>0)
             ].sort_values('away_diff_odds', ascending=False)
# Out:
#      match_api_id  home_team_api_id  away_team_api_id      away      draw  \
# 485       2030462              8306             10267  0.535942  0.236291
# 13        1989077              8472              8455  0.641058  0.194156
# 16        1989051              8678              8455  0.627695  0.226013
# 19        1988974              8466              8455  0.517304  0.242783
# 479       2030405              7878             10267  0.503558  0.274387
# 155       1988951              8678              9825  0.614319  0.190209
# 128       1989038              9817              8668  0.513831  0.263590
# 11        1988901              9826              8455  0.567356  0.243030
# 164       1989022              8678              8456  0.562276  0.234205
# 178       1989076              9850             10260  0.568548  0.224832
# 361       2030475              8558              9906  0.526626  0.258624
# 197       2002249              9810              8721  0.509436  0.218389
# 433       2030403              9864              8633  0.627014  0.214083
# 14        1988944              9817              8455  0.531533  0.235831
# 162       1988907              9817              8456  0.590007  0.237364
# 198       2002304              9904              8721  0.506402  0.236276
# 475       2030525              8306              8315  0.501230  0.279234
#
#          home  B365H  B365D  B365A   BWH   BWD   BWA   IWH  IWD   IWA  \
# 485  0.227767   2.38   3.25   3.10  2.35  3.20  3.00  2.40  3.3  2.75
# 13   0.164786   3.00   3.50   2.45  2.95  3.30  2.35  2.60  3.2  2.60
# 16   0.146291   3.10   3.50   2.40  2.90  3.30  2.35  2.65  3.3  2.50
# 19   0.239912   2.80   3.25   2.50  2.90  3.20  2.55  2.85  3.2  2.50
# 479  0.222055   2.88   3.20   2.55  2.85  3.20  2.60  2.65  3.3  2.50
# 155  0.195473   3.80   3.50   2.10  3.70  3.40  2.05  3.60  3.3  2.00
# 128  0.222579   3.40   3.30   2.15  3.40  3.25  2.15  2.95  3.1  2.40
# 11   0.189613   3.80   3.50   2.10  3.80  3.20  2.10  3.10  3.3  2.20
# 164  0.203519   3.75   3.60   2.10  3.60  3.40  2.00  3.60  3.3  2.00
# 178  0.206620   4.50   3.60   1.91  4.10  3.40  1.87  3.70  3.5  1.90
# 361  0.214750   4.00   3.10   2.05  4.33  3.30  1.85  3.60  3.3  2.00
# 197  0.272175   3.60   3.50   2.05  3.50  3.60  2.05  3.30  3.3  2.10
# 433  0.158903   4.75   3.80   1.73  4.75  3.90  1.72  5.00  4.0  1.60
# 14   0.232636   4.33   3.50   1.95  4.10  3.40  1.95  3.60  3.3  2.00
# 162  0.172629   5.00   4.00   1.75  4.75  3.75  1.75  4.70  3.6  1.70
# 198  0.257322   4.20   3.75   1.85  3.70  3.75  1.95  3.60  3.3  2.00
# 475  0.219537   4.00   3.60   1.91  4.00  3.50  1.87  3.60  3.3  2.00
#
#      home_odds  draw_odds  away_odds  outcome       home_team_name  \
# 485   4.390451   4.232068   1.865874        1        UD Las Palmas
# 13    6.068462   5.150505   1.559921        1           Sunderland
# 16    6.835676   4.424520   1.593129       -1          Bournemouth
# 19    4.168188   4.118896   1.933099       -1          Southampton
# 479   4.503389   3.644487   1.985868       -1           Granada CF
# 155   5.115805   5.257383   1.627820       -1          Bournemouth
# 128   4.492785   3.793772   1.946165        0              Watford
# 11    5.273895   4.114712   1.762560       -1       Crystal Palace
# 164   4.913547   4.269758   1.778487       -1          Bournemouth
# 178   4.839806   4.447770   1.758865       -1         Norwich City
# 361   4.656585   3.866611   1.898881       -1         RCD Espanyol
# 197   3.674111   4.578982   1.962954        1  Eintracht Frankfurt
# 433   6.293137   4.671093   1.594861        0            Málaga CF
# 14    4.298565   4.240329   1.881349        0              Watford
# 162   5.792772   4.212940   1.694895       -1              Watford
# 198   3.886183   4.232345   1.974714       -1          Hannover 96
# 475   4.555045   3.581232   1.995093        0        UD Las Palmas
#
#               away_team_name  home_diff_odds  away_diff_odds
# 485              Valencia CF       -1.990451        1.234126
# 13                   Chelsea       -3.068462        1.040079
# 16                   Chelsea       -3.735676        0.906871
# 19                   Chelsea       -1.268188        0.616901
# 479              Valencia CF       -1.623389        0.614132
# 155                  Arsenal       -1.315805        0.472180
# 128                  Everton       -1.092785        0.453835
# 11                   Chelsea       -1.473895        0.437440
# 164          Manchester City       -1.163547        0.321513
# 178        Manchester United       -0.339806        0.151135
# 361          Atlético Madrid       -0.326585        0.151119
# 197            VfL Wolfsburg       -0.074111        0.137046
# 433           Real Madrid CF       -1.293137        0.135139
# 14                   Chelsea        0.031435        0.118651
# 162          Manchester City       -0.792772        0.055105
# 198            VfL Wolfsburg        0.313817        0.025286
# 475  Athletic Club de Bilbao       -0.555045        0.004907

# %%
sum(pred_df_id_bk.draw>0.5)
# Out:
# 0

# %%
y_train.hist()

# %% [markdown]
# ## End
